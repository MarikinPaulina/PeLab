# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import rc
# %matplotlib inline

# %%
rc('font', family='Comic Sans MS')

# %%
charakterystyka = pd.read_csv('charakterystyka.csv')
Uwe = 160e-3 # w Woltach
dUwe = Uwe * 0.003 + 1e-3
charakterystyka['dUwy[V]'] = charakterystyka['Uwy[V]'] * 0.003 + 0.001
charakterystyka['ku[V/V]'] = charakterystyka['Uwy[V]']/Uwe
charakterystyka['dku[V/V]'] = np.sqrt((charakterystyka['dUwy[V]']/Uwe)**2+(charakterystyka['Uwy[V]']*dUwe/Uwe**2)**2)
charakterystyka['ku[dB]'] = 20*np.log10(charakterystyka['ku[V/V]'])
charakterystyka['dku[dB]'] = 20 * charakterystyka['dku[V/V]'] / np.log(10) / charakterystyka['ku[V/V]']
plt.errorbar(charakterystyka['f[Hz]'],charakterystyka['ku[dB]'],charakterystyka['dku[dB]'],0,'r.',label='Punkty pomiarowe')
plt.xscale('log')
plt.xlabel('f[Hz]')
plt.ylabel(r'$k_u$[dB]') 
plt.hlines(20.22,10,1e2,'g')
plt.hlines(17.22,10,1e3,'c','dashed',label='spadek o 3dB')
prosta, cov = np.polyfit(np.log10(charakterystyka['f[Hz]'][-4:]),charakterystyka['ku[dB]'][-4:],1,cov=True)
plt.plot(charakterystyka['f[Hz]'][-5:],np.polyval(prosta,np.log10(charakterystyka['f[Hz]'][-5:])),'g',label='Dopasowane proste')
plt.title('Zmierzona charakterystyka częstotliwościowa')
plt.legend()
plt.grid()
plt.savefig('Aproksymacja.png',dpi=300)
print('Nachylenie: {:.3f} +/- {:.3}'.format(prosta[0],np.sqrt(cov[0,0])))
cov
# Out:
# C:\Users\Paulina\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:606: RuntimeWarning: divide by zero encountered in true_divide
#   fac = resids / (len(x) - order - 2.0)
# Nachylenie: -19.520 +/- inf
# array([[ inf, -inf],
#        [-inf,  inf]])

# %%
prosta, cov = np.polyfit(np.log10(charakterystyka['f[Hz]'][-5:]),charakterystyka['ku[dB]'][-5:],1,cov=True)
np.log10(charakterystyka['f[Hz]'][-4:]), charakterystyka['ku[dB]'][-4:]
prosta, np.diag(np.sqrt(cov))
# Out:
# C:\Users\Paulina\Anaconda3\lib\site-packages\numpy\lib\polynomial.py:606: RuntimeWarning: divide by zero encountered in true_divide
#   fac = resids / (len(x) - order - 2.0)
# C:\Users\Paulina\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# (array([-19.52030089,  58.77962989]), array([ inf,  inf]))

# %%
np.__version__
# Out:
# '1.11.3'

# %%
def ku(f, R1 = 1e4,R2 = 1e5,C = 15e-9):
    omega = f*2*np.pi
    k = R2/(R1*np.sqrt(1+(omega*R2*C)**2))
    return 20*np.log10(k)

# %%
f = np.logspace(1,4,1000)
plt.plot(f,ku(f),'g',label='Krzywa teoretyczna')
plt.xscale('log')
plt.errorbar(charakterystyka['f[Hz]'],charakterystyka['ku[dB]'],charakterystyka['dku[dB]'],0,'r.',label='Punkty pomiarowe')
plt.xlabel('f[Hz]')
plt.ylabel(r'$k_u$[dB]') 
plt.grid()
plt.title('Zmierzona i teoretyczna charakterystyka częstotliwościowa')
plt.legend()
plt.savefig('Teoria.png',dpi=300)

# %%
pikna_tabelka_do_sprawozdania = pd.DataFrame()
pikna_tabelka_do_sprawozdania['f[Hz]'] = charakterystyka['f[Hz]']
pikna_tabelka_do_sprawozdania['ku[V/V]'] = charakterystyka['ku[V/V]']
pikna_tabelka_do_sprawozdania['delta ku[V/V]'] = charakterystyka['dku[V/V]']
pikna_tabelka_do_sprawozdania['kU[dB]'] = charakterystyka['ku[dB]']
pikna_tabelka_do_sprawozdania['delta ku[dB]'] = charakterystyka['dku[dB]']
mapper =  {'f[Hz]': '{0:.0f}',
           'ku[V/V]': '{0:.2f}',
           'delta ku[V/V]': '{0:.3f}',
           'kU[dB]': '{0:.2f}',
           'delta ku[dB]': '{0:.3f}'}

pikna_tabelka_do_sprawozdania = pikna_tabelka_do_sprawozdania.style.format(mapper)
pikna_tabelka_do_sprawozdania
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_a8da253a_ec82_11e7_bb80_78843ce30168" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   f[Hz]
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   ku[V/V]
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   delta ku[V/V]
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   kU[dB]
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   delta ku[dB]
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_a8da253a_ec82_11e7_bb80_78843ce30168"
#                  class="row_heading level0 row0" rowspan=1>
#                     0
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row0_col0"
#                  class="data row0 col0" >
#                     10
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row0_col1"
#                  class="data row0 col1" >
#                     10.62
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row0_col2"
#                  class="data row0 col2" >
#                     0.105
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row0_col3"
#                  class="data row0 col3" >
#                     20.53
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row0_col4"
#                  class="data row0 col4" >
#                     0.086
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a8da253a_ec82_11e7_bb80_78843ce30168"
#                  class="row_heading level0 row1" rowspan=1>
#                     1
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row1_col0"
#                  class="data row1 col0" >
#                     20
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row1_col1"
#                  class="data row1 col1" >
#                     10.62
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row1_col2"
#                  class="data row1 col2" >
#                     0.105
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row1_col3"
#                  class="data row1 col3" >
#                     20.53
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row1_col4"
#                  class="data row1 col4" >
#                     0.086
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a8da253a_ec82_11e7_bb80_78843ce30168"
#                  class="row_heading level0 row2" rowspan=1>
#                     2
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row2_col0"
#                  class="data row2 col0" >
#                     50
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row2_col1"
#                  class="data row2 col1" >
#                     9.38
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row2_col2"
#                  class="data row2 col2" >
#                     0.093
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row2_col3"
#                  class="data row2 col3" >
#                     19.44
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row2_col4"
#                  class="data row2 col4" >
#                     0.086
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a8da253a_ec82_11e7_bb80_78843ce30168"
#                  class="row_heading level0 row3" rowspan=1>
#                     3
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row3_col0"
#                  class="data row3 col0" >
#                     100
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row3_col1"
#                  class="data row3 col1" >
#                     7.50
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row3_col2"
#                  class="data row3 col2" >
#                     0.075
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row3_col3"
#                  class="data row3 col3" >
#                     17.50
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row3_col4"
#                  class="data row3 col4" >
#                     0.087
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a8da253a_ec82_11e7_bb80_78843ce30168"
#                  class="row_heading level0 row4" rowspan=1>
#                     4
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row4_col0"
#                  class="data row4 col0" >
#                     200
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row4_col1"
#                  class="data row4 col1" >
#                     4.75
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row4_col2"
#                  class="data row4 col2" >
#                     0.048
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row4_col3"
#                  class="data row4 col3" >
#                     13.53
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row4_col4"
#                  class="data row4 col4" >
#                     0.089
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_a8da253a_ec82_11e7_bb80_78843ce30168"
#                  class="row_heading level0 row5" rowspan=1>
#                     5
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row5_col0"
#                  class="data row5 col0" >
#                     500
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row5_col1"
#                  class="data row5 col1" >
#                     2.06
#
#
#
#                 <td id="T_a8da253a_ec82_11e7_bb80_78843ce30168row5_col2"
#                  class="data row5 col2" >
#                     0.023

# %%
wtorniki = pd.read_csv('prad_obciazenia.csv')
wtorniki['I[mA]'] = wtorniki['I[A]']*1e3 
bezWtornika = wtorniki[wtorniki['wtornik'] == 0]
zWtornikiem = wtorniki[wtorniki['wtornik'] == 1]
plt.plot(bezWtornika['I[mA]'],bezWtornika['U[V]'],'o-',label='Bez wtórnika')
plt.plot(zWtornikiem['I[mA]'],zWtornikiem['U[V]'],'o-',label='Z wtórnikiem')
plt.ylabel('U [V]')
plt.xlabel(r'I [mA]')
plt.grid()
plt.legend()
plt.title('Charakterystyki napięcia wyjściowego od prądu obciążenia \n dla regulowanego źródła napięciowego')
plt.savefig('Wtorniki.png',dpi = 300)

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B4AE-DFF8
#
#  Directory of C:\Users\Paulina\Politechnika\Semestr_III\PE\PeLab\09-O�miorniki
#
# 2017-12-29  10:20    <DIR>          .
# 2017-12-29  10:20    <DIR>          ..
# 2017-12-28  15:50    <DIR>          .ipynb_checkpoints
# 2017-12-29  10:20            97˙956 Aproksymacja.png
# 2017-12-28  15:22                93 charakterystyka.csv
# 2017-12-29  10:20            47˙761 O�miorniki.ipynb
# 2017-12-28  15:25                70 prĄd_obciazenia.csv
# 2017-12-29  10:20           105˙940 Teoria.png
#                5 File(s)        251˙820 bytes
#                3 Dir(s)  74˙288˙607˙232 bytes free
