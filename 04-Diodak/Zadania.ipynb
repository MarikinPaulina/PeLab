# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='Comic Sans MS')

# %%
# U = np.linspace(0,200)
# def Is(U,IS=1,UnakT =23):
#     return IS*(np.exp(U*UnakT)-1)
# plt.plot(U,Is(U,1/175))
Ud = np.linspace(0,275)
def Id(U,UD,RR):
    return (U)/RR - UD
plt.plot([175,4825],[1,0])
plt.plot(175,1,'ro')
def i(U,b):
    return -U*(1/100)+b
plt.plot(Ud,i(Ud,2.75))
plt.grid()
plt.xlabel('U[mV]')
plt.ylabel('I[mA]')
plt.title('Wykres prostych obciążenia diody')
plt.show()
